# %% [markdown]
# ## Get Single Event Data from BL4A (multi-run mode)
#
# Version 2.0
#
# T. Charlton
#
# M.R. Fitzsimmons
#
# Please cite use of this code as: https://doi.org/10.5281/zenodo.3967680
#
# 096.22.2020
#
# Added report of mean proton charge per spin state.
#
# Added dictionary functionality.
#
# 06.28.2020 Add process variable for MAGH
# 09.14.2020 Add "-" option to select continuous range of files.
# 11.04.2020 Added total proton charge exposure for each cross-section as an additional column, and variable pcsum

# %% [markdown]
# ## This Notebook facilitates extraction of single event mode data from multiple runs
# This notebook needs to be run on analysis.sns.gov.  The files once written can be transferred to a local machine for further processing.
#
#     1) Sequentially loads many nexus event files.
#     2) Obtains per pulse proton charge for each event.
#     3) Removes proton flash.
#     4) Filter events based on polarization state.
#     5) Writes information in text and python binary files.

# %% [markdown]
# ## User provides list of run numbers to process.
#     1) User provides directory path to IPTS experiment.
#     2) User provides a list of run numbers in the array called "run_numbers".

# %%
import os
# %cd ~
cwd_path = os.getcwd()
print('Current working directory: %s'%cwd_path)

#Example:
#directory_path = cwd_path+r'/data/SNS/REF_M/IPTS-23100/' # user input
#run_numbers = ['32400', '32398'] # user input

#IPTS-23100
#directory_path = cwd_path+r'/data/SNS/REF_M/IPTS-23100/' # user input
#run_numbers = ['32400', '32398','32411','32412','32413','32414','32415','32416' ] # user input
#run_numbers = ['32397'] # user input

#IPTS-24314 Liz
#directory_path = cwd_path+r'/data/SNS/REF_M/IPTS-24314/' # user input
#run_numbers = ['34601','34605','34602','34603','34636','34637',
#               '34638','34639','34668','34669','34670','34671','34672',
#               '34644', '34645','34673' ] # user input

#IPTS-24772 Misha
#directory_path = cwd_path+r'/data/SNS/REF_M/IPTS-24772/' # user input
#run_numbers = ['35529','35530','35531','35532','35533','35534',
#               '35535','35536','35537'] # user input
#run_numbers = ['35538','35539','35540','35542','35543','35544','35545'] # user input
#run_numbers = ['35547','35548','35549','35550','35551','35552','35553'] # user input
#run_numbers = ['35558'] # user input
#run_numbers = ['35547','-','35553']
#run_numbers = ['35554','35555','35556','35557','35558','35559'] # user input


#IPTS-18520
# Fails for this IPTS because the experiment was taken pre-epics transformation.

#IPTS-21391
directory_path = cwd_path+r'/data/SNS/REF_M/IPTS-21391/' # user input
#run_numbers = ['35096', '35097','35098' ] # user input
#run_numbers = ['35000'] # user input 100G 
#run_numbers = ['36005','-','36054']
#run_numbers = ['36055']

#run_numbers = ['36153','-','36202']
#run_numbers = ['36056','-','36105']
#run_numbers = ['36244','-','36250']
#run_numbers = ['36264','-','36336']
#run_numbers = ['36338','-','36437']
#run_numbers = ['36443','-','36542']
#run_numbers = ['36252']
#run_numbers = ['36563','-','36662']
#run_numbers = ['36546','-','36548']
#run_numbers = ['36663','-','36762']

#run_numbers = ['36252','36546','36547','36548','36556']
#run_numbers = ['36557','36558']
#run_numbers = ['36546']


#for absolute flux
run_numbers = ['35939','-','35987']



# This bit of code will check whether the user defined a range with the '-' symbol. If so create a continuous range of run numbers
if any('-' in s for s in run_numbers):
    i,j = int(run_numbers[0]),int(run_numbers[len(run_numbers)-1])
    if j<i:
        j,i = i,j
    run_numbers = []
    for k in range(i,j+1,1):
        run_numbers.append(str(k))
print('Run numbers to be processed:')
print(run_numbers)
    
NumpyMean = True # calculate mean pcharge using numpy (will slightly underestimate accelerator intentional drops)
NumpyMean = False # rigorous calculation
# Out:
# /SNS/users/mf3
# Current working directory: /SNS/users/mf3
# Run numbers to be processed:
# ['35939', '35940', '35941', '35942', '35943', '35944', '35945', '35946', '35947', '35948', '35949', '35950', '35951', '35952', '35953', '35954', '35955', '35956', '35957', '35958', '35959', '35960', '35961', '35962', '35963', '35964', '35965', '35966', '35967', '35968', '35969', '35970', '35971', '35972', '35973', '35974', '35975', '35976', '35977', '35978', '35979', '35980', '35981', '35982', '35983', '35984', '35985', '35986', '35987']

# %% [markdown]
# ## Code to import required libraries (run in a Mantid compatible kernal)

# %%
import sys, math, getopt, glob, operator
import numpy as np
import numpy.ma as ma 
np.warnings.filterwarnings('ignore')
import mantid
from mantid.simpleapi import *
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from mantid import plots
from datetime import datetime

# Function to identify states of the two flippers for an event.
def filter_cross_sections(ws):
    """
        Filter events according to an aggregated state log.
        :param str file_path: file to read

        BL4A:SF:ICP:getDI

        015 (0000 1111): SF1=OFF, SF2=OFF, SF1Veto=OFF, SF2Veto=OFF
        047 (0010 1111): SF1=ON, SF2=OFF, SF1Veto=OFF, SF2Veto=OFF
        031 (0001 1111): SF1=OFF, SF2=ON, SF1Veto=OFF, SF2Veto=OFF
        063 (0011 1111): SF1=ON, SF2=ON, SF1Veto=OFF, SF2Veto=OFF
        
        From Mathieu Doucet.
    """
    state_log = "BL4A:SF:ICP:getDI"
    states = {'Off_Off': 15,
              'On_Off': 47,
              'Off_On': 31,
              'On_On': 63}
    cross_sections = []
    cross_sections_dict = {}

    for pol_state in states:
        try:
            _ws = FilterByLogValue(InputWorkspace=ws, 
                                   LogName=state_log, 
                                   TimeTolerance=0.1,
                                   MinimumValue=states[pol_state],
                                   MaximumValue=states[pol_state],
                                   LogBoundary='Left',
                                   OutputWorkspace='%s_%s'%(ws.getRunNumber(),
                                                            pol_state))
            _ws.getRun()['cross_section_id'] = pol_state
            if _ws.getNumberEvents() > 0:
                cross_sections.append(_ws)
                cross_sections_dict[pol_state] =_ws
        except:
            mantid.logger.error("Could not filter %s: %s"%(pol_state,
                                                           sys.exc_info()[1]))

    return cross_sections, cross_sections_dict

# %% [markdown]
# ## Main loop
#     1) Get data for the run.
#     2) Remove flash.
#     3) Separate into states.
#     4) Write files.
#     5) Repeat

# %%
# All output files will be designated by run number, followed by:
output_file_base = '_events'

_nruns = len(run_numbers)

for _runid in range(_nruns):
    InputFile = directory_path+r'nexus/REF_M_'+run_numbers[_runid]+'.nxs.h5'
    print('Processing: %s'%InputFile)
    OutputFile = directory_path+r'shared/'+run_numbers[_runid]+output_file_base
    
# Get the data
    RawEvents=LoadEventNexus(InputFile)
    RawEvents=Rebin(RawEvents, "2e4, 1., 6e4", PreserveEvents=True) # so that we can plot things in more that one time bin
    
# Remove the proton flash    
    NoProtonFlash=RemovePromptPulse(RawEvents, Width=300,Frequency=60.0)   
    
# Get the proton charge per pulse and absolute time for each pulse.
    pc_values = NoProtonFlash.getRun()['proton_charge'].value
    pc_times  = NoProtonFlash.getRun()['proton_charge'].times    
    
# Filter flipper states
    (ListOfFilteredCrossSections,
     DictOfFilteredCrossSections)=filter_cross_sections(NoProtonFlash)
    # Note: Since the list and the dictionary point to the same set of 
    #       Mantid workspaces, changing one will change the other.
    
# Calculate mean proton charge over entire measurement in order to filter out outliers
   
    if NumpyMean:   # Choose your way to calculate the mean
        #True.  = > Use numpy
        # Exclude pc values corresponding to zero which occur often if not running at 60Hz, or not running
        _index = np.argwhere(pc_values>0)
        mean_pc = np.mean(pc_values[_index])
        rms_width = np.std(pc_values[_index])
        
    else: # False => Use method below
        charge_sum = np.double(0.)
        charge2_sum = np.double(0.)
        n_sum = np.int32(0)
        for K in DictOfFilteredCrossSections.keys(): # As long as we don't  
                                                     # care about what order   
                                                     # we take the cross sections
                                                     # in we can do this.
            for x in range(256*304):
                f=DictOfFilteredCrossSections[K].getSpectrum(x) # spectrum for a single pixel vs. time
                tofs=f.getTofs(); PulseTimes = f.getPulseTimes(); 
                for i in range(f.getNumberEvents()): 
                    t = mantid.kernel.DateAndTime(PulseTimes[i]).to_datetime64()
                    _index = np.searchsorted(pc_times, t)
                    charge = pc_values[_index]
                    if charge != 0:
                        charge_sum = charge_sum + charge
                        charge2_sum = charge2_sum + charge*charge
                        n_sum = n_sum + 1
        mean_pc = charge_sum/n_sum # mean per pulse
        rms_width = np.sqrt((charge2_sum-2*mean_pc*charge_sum+n_sum*mean_pc*mean_pc)/(n_sum-1))
    print('Mean proton charge: %.2f (%.2f)'%(mean_pc,rms_width))

# Write event lists while excluding outliers based on proton current
    n_sig = 4 # accept events for frames having proton charge within 4-sigma
    for K in DictOfFilteredCrossSections.keys(): 

        f=DictOfFilteredCrossSections[K]
        pc_Kvalues = f.getRun()['proton_charge'].value
        pc_Ktimes  = f.getRun()['proton_charge'].times
        
        pcChargeSumK = np.sum(pc_Kvalues[np.where(np.abs(pc_Kvalues-mean_pc) < n_sig/2*rms_width)], dtype=np.int64)      
        
        OFile = open(OutputFile+'_%s.txt'%(K), 'w')
        print('Writing: '+OutputFile+'_%s.txt'%(K))
        OutList =[] ; OutStrings=[]
        for x in range(256*304):
            f=DictOfFilteredCrossSections[K].getSpectrum(x) # spectrum for a single pixel vs. time
            tofs=f.getTofs(); PulseTimes = f.getPulseTimes(); 
            for i in range(f.getNumberEvents()): 
                t = mantid.kernel.DateAndTime(PulseTimes[i]).to_datetime64()
                _index = np.searchsorted(pc_times, t)
                charge = pc_values[_index]
                dt64 = np.datetime64(pc_times[_index])
# OutList contains n-events defined by absolute time of t0 in ns and string forms, tof (micro-s), pixel-id, proton charge
# Here apply filter, only append if within 1-sigma of mean proton charge
                if np.abs(charge-mean_pc) < n_sig/2*rms_width:        
                    OutList.append((dt64.astype(datetime),tofs[i], x, charge, pcChargeSumK))
                    OutStrings.append("%s\t%.10f\t%d\t%.10f\t%i\n"%(PulseTimes[i],
                                   tofs[i], x, charge, pcChargeSumK))    
        OutStrings.sort()
        for item in OutStrings: 
            OFile.write(item)
        OFile.close()
        OutList.sort()    
        t0_time = np.zeros(len(OutList), dtype=np.uint64)
        t0_time_string = []
        tof = np.zeros(len(OutList), dtype=np.float32)
        pixel_id = np.zeros(len(OutList), dtype=np.uint32)
        pcharge = np.zeros(len(OutList), dtype=np.float32)
        pcsum = np.zeros(len(OutList), dtype=np.int64)
        for i in range(len(OutList)):
            x = OutList[i]
            t0_time[i] = x[0]
            t0_time_string.append(np.datetime64(x[0],'ns'))
            tof[i] = x[1]
            pixel_id[i] = x[2]
            pcharge[i] = x[3]    
            pcsum[i] = x[4]
        np.savez(OutputFile+'_%s.npz'%(K),t0_time,t0_time_string,tof,pixel_id,pcharge,pcsum)

# Write slow log data
    RunInfo=RawEvents.getRun()
    instrument = RawEvents.getInstrument()
    source = instrument.getSource()
    sample = instrument.getSample()
    Parameters = instrument.getParameterNames()
    Source_Sample_Distance = sample.getDistance(source) # m
    Det=instrument.getDetector(int(256*304/2))  # distance from sample to center of detector
    Sample_Detector_Center_Distance = Det.getDistance(sample) # m
    pixel_to_coordinate = np.zeros((256*304,3), dtype=np.float32)
    for i in range(256*304):
        Det=instrument.getDetector(i)  # i is the detetector element index
        PixelPos = Det.getPos()
        pixel_to_coordinate[i,0]= Det.getDistance(sample) # m
        pixel_to_coordinate[i,1]= np.arctan(float(PixelPos[0])/float(PixelPos[2])) # radians
        pixel_to_coordinate[i,2]= np.arctan(float(PixelPos[1])/float(PixelPos[2])) # radians
    OutStrings2 = []
    OutStrings2.append('Source to sample distance: %s [m]\n'%Source_Sample_Distance)
    OutStrings2.append('Sample to PSD center distance: %s [m]\n'%Sample_Detector_Center_Distance)

    TemperatureLog= RunInfo.getLogData('BL4A:SE:Lakeshore:KRDG1')
    OutStrings2.append('Mean temperature: %.2f(%.2f) [K]\n'%(np.mean(TemperatureLog.value[:]),np.std(TemperatureLog.value[:])))

    DANGLELog=RunInfo.getLogData('DANGLE')
    OutStrings2.append('Detector angle: %.2f(%.2f) [degrees]\n'%(np.mean(DANGLELog.value[:]),np.std(DANGLELog.value[:])))

    DANGLE0Log=RunInfo.getLogData('DANGLE0')
    OutStrings2.append('Detector offset angle: %.2f(%.2f) [degrees]\n'%(np.mean(DANGLE0Log.value[:]),np.std(DANGLE0Log.value[:])))
    
    SANGLELog=RunInfo.getLogData('SANGLE')
    OutStrings2.append('Sample angle: %.2f(%.2f) [degrees]\n'%(np.mean(SANGLELog.value[:]),np.std(SANGLELog.value[:])))

    C0Log= RunInfo.getLogData('BL4A:CS:ExpPlan:DirectPixel')
    OutStrings2.append('Direct Beam Pixel: %s\n'%np.mean(C0Log.value[:]))

    ChopperFreqLog= RunInfo.getLogData('BL4A:Chop:Gbl:Speed:Req')
    OutStrings2.append('Chopper Frequency: %s [Hz]\n'%np.mean(ChopperFreqLog.value[:]))

    LambdaBarLog= RunInfo.getLogData('BL4A:Chop:Gbl:Wavelength:Req')
    OutStrings2.append('Mean wavelength: %s [Angstroms]\n'%np.mean(LambdaBarLog.value[:]))

    EMagLog= RunInfo.getLogData('BL4A:SE:Bruker:FieldSP')
    OutStrings2.append('Electromagnet induction: %.4f (%.4f) [T]\n'%(np.mean(EMagLog.value[:]),np.std(EMagLog.value[:])))

    try:
        MagHSPLog= RunInfo.getLogData('BL4A:SE:MagH:SP')
        OutStrings2.append('MagH induction (set point): %.4f (%.4f) [T]\n'%(np.mean(MagHSPLog.value[:]),np.std(MagHSPLog.value[:])))
        MagHLog= RunInfo.getLogData('BL4A:SE:MagH:ReadField')
        OutStrings2.append('MagH induction (actual): %.4f (%.4f) [T]\n'%(np.mean(MagHLog.value[:]),np.std(MagHLog.value[:])))
        MagH = True
    
    except RuntimeError:
        print('No MagH process variable in nexus file.')
        MagH = False # new S.E. not all files have this variable

    OFile = open(OutputFile+'_log.txt', 'w')
    print('Writing: '+OutputFile+'_log.txt')
    for item in OutStrings2: 
        OFile.write(item)
    OFile.close()

    if MagH:
        np.savez(OutputFile+'_log.npz',pixel_to_coordinate,
                 Source_Sample_Distance,
                 Sample_Detector_Center_Distance,
                 TemperatureLog.times,TemperatureLog.value,
                 DANGLELog.times,DANGLELog.value,
                 DANGLE0Log.times,DANGLE0Log.value,
                 SANGLELog.times,SANGLELog.value,
                 C0Log.times,C0Log.value,
                 ChopperFreqLog.times,ChopperFreqLog.value,
                 LambdaBarLog.times,LambdaBarLog.value,
                 EMagLog.times,EMagLog.value,
                 MagHSPLog.times,MagHSPLog.value,
                 MagHLog.times,MagHLog.value)
    else:
        np.savez(OutputFile+'_log.npz',pixel_to_coordinate,
                 Source_Sample_Distance,
                 Sample_Detector_Center_Distance,
                 TemperatureLog.times,TemperatureLog.value,
                 DANGLELog.times,DANGLELog.value,
                 DANGLE0Log.times,DANGLE0Log.value,
                 SANGLELog.times,SANGLELog.value,
                 C0Log.times,C0Log.value,
                 ChopperFreqLog.times,ChopperFreqLog.value,
                 LambdaBarLog.times,LambdaBarLog.value,
                 EMagLog.times,EMagLog.value)
# Out:
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35939.nxs.h5
# Mean proton charge: 23364486.28 (37911.56)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35939_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35939_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35940.nxs.h5
# Mean proton charge: 23349966.00 (48685.40)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35940_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35940_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35941.nxs.h5
# Mean proton charge: 23351922.72 (42305.00)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35941_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35941_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35942.nxs.h5
# Mean proton charge: 23380497.24 (87180.69)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35942_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35942_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35943.nxs.h5
# Mean proton charge: 23360734.25 (43586.93)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35943_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35943_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35944.nxs.h5
# Mean proton charge: 23438554.00 (40873.02)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35944_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35944_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35945.nxs.h5
# Mean proton charge: 23392393.40 (84874.23)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35945_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35945_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35946.nxs.h5
# Mean proton charge: 23418498.41 (53077.36)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35946_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35946_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35947.nxs.h5
# Mean proton charge: 23352483.57 (85990.61)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35947_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35947_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35948.nxs.h5
# Mean proton charge: 23235284.79 (67051.77)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35948_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35948_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35949.nxs.h5
# Mean proton charge: 23253670.98 (42230.01)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35949_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35949_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35950.nxs.h5
# Mean proton charge: 23213766.89 (45339.24)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35950_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35950_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35951.nxs.h5
# Mean proton charge: 23214954.17 (42875.13)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35951_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35951_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35952.nxs.h5
# Mean proton charge: 23240880.48 (43884.97)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35952_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35952_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35953.nxs.h5
# Mean proton charge: 23229777.89 (47605.43)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35953_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35953_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35954.nxs.h5
# Mean proton charge: 23215213.12 (43203.84)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35954_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35954_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35955.nxs.h5
# Mean proton charge: 23205224.27 (38067.19)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35955_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35955_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35956.nxs.h5
# Mean proton charge: 23209398.56 (60571.27)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35956_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35956_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35957.nxs.h5
# Mean proton charge: 23254389.29 (127281.11)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35957_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35957_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35958.nxs.h5
# Mean proton charge: 23314699.55 (56838.99)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35958_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35958_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35959.nxs.h5
# Mean proton charge: 23312977.30 (75051.29)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35959_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35959_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35960.nxs.h5
# Mean proton charge: 23350415.23 (67019.10)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35960_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35960_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35961.nxs.h5
# Mean proton charge: 23307226.00 (40322.75)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35961_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35961_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35962.nxs.h5
# Mean proton charge: 23358330.94 (64416.92)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35962_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35962_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35963.nxs.h5
# Mean proton charge: 23380796.27 (83509.70)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35963_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35963_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35964.nxs.h5
# Mean proton charge: 23380566.50 (41809.76)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35964_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35964_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35965.nxs.h5
# Mean proton charge: 23394711.17 (137719.81)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35965_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35965_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35966.nxs.h5
# Mean proton charge: 23354867.52 (51097.28)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35966_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35966_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35967.nxs.h5
# Mean proton charge: 23415059.90 (55468.47)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35967_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35967_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35968.nxs.h5
# Mean proton charge: 23430011.86 (48967.61)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35968_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35968_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35969.nxs.h5
# Mean proton charge: 23342110.35 (51145.86)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35969_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35969_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35970.nxs.h5
# Mean proton charge: 23330079.22 (39581.63)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35970_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35970_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35971.nxs.h5
# Mean proton charge: 23315235.72 (38196.95)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35971_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35971_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35972.nxs.h5
# Mean proton charge: 23339019.87 (38904.11)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35972_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35972_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35973.nxs.h5
# Mean proton charge: 23390782.12 (46356.88)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35973_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35973_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35974.nxs.h5
# Mean proton charge: 23382480.07 (128144.42)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35974_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35974_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35975.nxs.h5
# Mean proton charge: 23328881.98 (41432.14)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35975_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35975_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35976.nxs.h5
# Mean proton charge: 23363066.73 (69357.87)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35976_events_Off_Off.txt
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35976_events_log.txt
# Processing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/nexus/REF_M_35977.nxs.h5
# Mean proton charge: 23316250.58 (54532.03)
# Writing: /SNS/users/mf3/data/SNS/REF_M/IPTS-21391/shared/35977_events_Off_Off.txt
